# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarby/fruit-and-vegetable-price-calculation-using-yolo/blob/main/model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================
# 🥭 STEP 1: Install YOLO and dependencies
# ==============================================
# !pip install ultralytics roboflow --quiet

from ultralytics import YOLO
import torch

# ✅ Check GPU
print("GPU available:", torch.cuda.is_available())
torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only"
# Out:
# GPU available: True
# 'Tesla T4'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tEa3ycVdSYzl84Xf1eS6")
project = rf.workspace("object-detection-uitvg").project("572_fruits_vegetables-lp1hf")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo detect train \
    data={dataset.location}/data.yaml \
    model=yolov8n.pt \
    epochs=50 \
    imgsz=640 \
    batch=16 \
    name=fruit_veg_yolo
# Out:
# Ultralytics 8.3.206 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
files.download('runs/detect/fruit_veg_yolo/weights/best.pt')
